# %%
# !pip install streamlit
# Out:
# ...
#      --------------------------------------- 10.1/10.1 MB 20.9 MB/s eta 0:00:00
# ...
#      ------------------------------------- 181.2/181.2 KB 11.4 MB/s eta 0:00:00
# ...
#      -------------------------------------- 111.5/111.5 KB 6.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#      ------------------------------------- 812.8/812.8 KB 25.9 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 4.3/4.3 MB 30.5 MB/s eta 0:00:00
# ...
#      --------------------------------------- 16.1/16.1 MB 27.3 MB/s eta 0:00:00
# ...
#      ------------------------------------- 895.9/895.9 KB 18.8 MB/s eta 0:00:00
# ...
#      -------------------------------------- 164.8/164.8 KB 9.7 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 63.1/63.1 KB ? eta 0:00:00
# ...
#      ------------------------------------- 339.5/339.5 KB 21.9 MB/s eta 0:00:00
# ...

# %%
# !streamlit hello
# Out:
# ^C
